# %% [markdown]
# # Importing the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

sns.set()

# %%
import warnings

# Ignore a specific warning by category
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Importing the Database

# %%
raw_data = pd.read_csv('ml_datasource.csv')

# %%
raw_data.head()
# Out:
#   student_country  days_on_platform  minutes_watched  courses_started  \
# 0              US               288            358.1                1
# 1              SG               260              1.7                1
# 2              TR               260             22.4                1
# 3              KE               259             18.8                1
# 4              IN               259            118.0                2
#
#    practice_exams_started  practice_exams_passed  minutes_spent_on_exams  \
# 0                       2                      2                   15.81
# 1                       1                      0                   16.00
# 2                       1                      0                    0.93
# 3                       1                      1                   14.63
# 4                       2                      1                   16.48
#
#    purchased
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data = raw_data.copy()

# %%
data.describe(include = 'all')
# Out:
#        student_country  days_on_platform  minutes_watched  courses_started  \
# count            17752      17761.000000     17761.000000     17761.000000
# unique             171               NaN              NaN              NaN
# top                 IN               NaN              NaN              NaN
# freq              3365               NaN              NaN              NaN
# mean               NaN        123.205112        31.082906         1.196442
# std                NaN         90.675102        90.593660         0.646788
# min                NaN          0.000000         0.100000         1.000000
# 25%                NaN         42.000000         1.100000         1.000000
# 50%                NaN        113.000000         6.800000         1.000000
# 75%                NaN        204.000000        34.300000         1.000000
# max                NaN        292.000000      5312.300000        16.000000
#
#         practice_exams_started  practice_exams_passed  minutes_spent_on_exams  \
# count             17761.000000           17761.000000            17761.000000
# unique                     NaN                    NaN                     NaN
# top                        NaN                    NaN                     NaN
# freq                       NaN                    NaN                     NaN
# mean                  0.277800               0.176341                1.242772
# std                   1.659998               1.099900                7.755386
# min                   0.000000               0.000000                0.000000
# 25%                   0.000000               0.000000                0.000000
# 50%                   0.000000               0.000000                0.000000
# 75%                   0.000000               0.000000                0.000000
# max                  76.000000              63.000000              457.410000
#
#            purchased
# count   17761.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.091830
# std         0.288795
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
data.dtypes
# Out:
# student_country            object
# days_on_platform            int64
# minutes_watched           float64
# courses_started             int64
# practice_exams_started      int64
# practice_exams_passed       int64
# minutes_spent_on_exams    float64
# purchased                   int64
# dtype: object

# %% [markdown]
# #### Observe the distribution of the dataset

# %%
# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(12, 12))

# Plot KDE plots on subplots
sns.kdeplot(data['minutes_spent_on_exams'], ax=axes[0, 0], color='blue', label='Minutes Spent on Exams')
sns.kdeplot(data['courses_started'], ax=axes[0, 1], color='green', label='Courses Started')
sns.kdeplot(data['minutes_watched'], ax=axes[0, 2], color='red', label='Minutes Watched')
sns.kdeplot(data['days_on_platform'], ax=axes[1, 0], color='purple', label='Days on Platform')
sns.kdeplot(data['practice_exams_passed'], ax=axes[1, 1], color='yellow', label='Practice Exams Passed')
sns.kdeplot(data['practice_exams_started'], ax=axes[1, 2], color='skyblue', label='Practice Exams Started')

# Set titles for subplots
axes[0, 0].set_title('Minutes Spent on Exams')
axes[0, 1].set_title('Courses Started')
axes[0, 2].set_title('Minutes Watched')
axes[1, 0].set_title('Days on Platform')
axes[1, 1].set_title('Practice Exams Passed')
axes[1, 2].set_title('Practice Exams Started')

# Add legend to each subplot
for ax in axes.flat:
    ax.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Removing Outliers

# %%
data= data[data['minutes_watched'] <= 1000] ## drop Minutes watched larger than 1,000

# %%
data = data[data['courses_started'] <= 10] ## Number of courses surpassing 10

# %%
data = data[data['practice_exams_started'] <= 10] ### Number of practice exams started higher than 10

# %%
data= data[data['minutes_spent_on_exams'] <= 40] ### Minutes spent on exams going beyond 40 minutes

# %%
data_no_outliers = data.copy()

# %%
data_no_outliers.shape
# Out:
# (17626, 8)

# %%
# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 10))

# Plot KDE plots on subplots
sns.kdeplot(data_no_outliers['minutes_spent_on_exams'], ax=axes[0, 0], color='blue', label='Minutes Spent on Exams')
sns.kdeplot(data_no_outliers['courses_started'], ax=axes[0, 1], color='green', label='Courses Started')
sns.kdeplot(data_no_outliers['minutes_watched'], ax=axes[0, 2], color='red', label='Minutes Watched')
sns.kdeplot(data_no_outliers['days_on_platform'], ax=axes[1, 0], color='purple', label='Days on Platform')
sns.kdeplot(data_no_outliers['practice_exams_passed'], ax=axes[1, 1], color='yellow', label='Practice Exams Passed')
sns.kdeplot(data_no_outliers['practice_exams_started'], ax=axes[1, 2], color='skyblue', label='Practice Exams Started')

# Set titles for subplots
axes[0, 0].set_title('Minutes Spent on Exams')
axes[0, 1].set_title('Courses Started')
axes[0, 2].set_title('Minutes Watched')
axes[1, 0].set_title('Days on Platform')
axes[1, 1].set_title('Practice Exams Passed')
axes[1, 2].set_title('Practice Exams Started')

# Add legend to each subplot
for ax in axes.flat:
    ax.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
## create new data frame
new_df = data_no_outliers.copy()
new_df.shape
# Out:
# (17626, 8)

# %%
# Reset the index and drop the old index
new_df.reset_index(drop=True, inplace=True)

# %%
new_df.describe(include = 'all')
# Out:
#        student_country  days_on_platform  minutes_watched  courses_started  \
# count            17618      17626.000000     17626.000000     17626.000000
# unique             171               NaN              NaN              NaN
# top                 IN               NaN              NaN              NaN
# freq              3351               NaN              NaN              NaN
# mean               NaN        123.454102        27.145342         1.177295
# std                NaN         90.773394        56.290650         0.559075
# min                NaN          0.000000         0.100000         1.000000
# 25%                NaN         41.000000         1.100000         1.000000
# 50%                NaN        113.000000         6.700000         1.000000
# 75%                NaN        204.000000        33.400000         1.000000
# max                NaN        292.000000       994.200000         9.000000
#
#         practice_exams_started  practice_exams_passed  minutes_spent_on_exams  \
# count             17626.000000           17626.000000            17626.000000
# unique                     NaN                    NaN                     NaN
# top                        NaN                    NaN                     NaN
# freq                       NaN                    NaN                     NaN
# mean                  0.183195               0.119029                0.778405
# std                   0.817034               0.588701                3.476651
# min                   0.000000               0.000000                0.000000
# 25%                   0.000000               0.000000                0.000000
# 50%                   0.000000               0.000000                0.000000
# 75%                   0.000000               0.000000                0.000000
# max                  10.000000               9.000000               40.000000
#
#            purchased
# count   17626.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.092137
# std         0.289227
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %% [markdown]
# ### Checking for Multicollinearity

# %%
# Select the independent variables for which you want to check multicollinearity
variables = new_df[["days_on_platform", "minutes_watched",
                    "courses_started", "practice_exams_started", 
                    "practice_exams_passed", "minutes_spent_on_exams","purchased"]]

# Add a constant column for the VIF calculation
X = add_constant(variables)

# Calculate VIF for each variable
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                  Variable       VIF
# 0                   const  8.369010
# 1        days_on_platform  1.211302
# 2         minutes_watched  1.585815
# 3         courses_started  1.364688
# 4  practice_exams_started  9.744814
# 5   practice_exams_passed  7.523045
# 6  minutes_spent_on_exams  3.196568
# 7               purchased  1.240166

# %%
columns_with_high_VIF = ['practice_exams_started','practice_exams_passed']
data_no_mult = new_df.drop(columns = columns_with_high_VIF, inplace = True)

# %% [markdown]
# ### Dealing with NaN Values

# %%
new_df.isnull()
# Out:
#        student_country  days_on_platform  minutes_watched  courses_started  \
# 0                False             False            False            False
# 1                False             False            False            False
# 2                False             False            False            False
# 3                False             False            False            False
# 4                False             False            False            False
# ...                ...               ...              ...              ...
# 17621            False             False            False            False
# 17622            False             False            False            False
# 17623            False             False            False            False
# 17624            False             False            False            False
# 17625            False             False            False            False
#
#        minutes_spent_on_exams  purchased
# 0                       False      False
# 1                       False      False
# 2                       False      False
# 3                       False      False
# 4                       False      False
# ...                       ...        ...
# 17621                   False      False
# 17622                   False      False
# 17623                   False      False
# 17624                   False      False
# 17625                   False      False
#
# [17626 rows x 6 columns]

# %%
new_df.isnull().sum()
# Out:
# student_country           8
# days_on_platform          0
# minutes_watched           0
# courses_started           0
# minutes_spent_on_exams    0
# purchased                 0
# dtype: int64

# %%
new_df['student_country'] = new_df['student_country'].fillna('NAM', axis = 0)

# %%
new_df
# Out:
#       student_country  days_on_platform  minutes_watched  courses_started  \
# 0                  US               288            358.1                1
# 1                  SG               260              1.7                1
# 2                  TR               260             22.4                1
# 3                  KE               259             18.8                1
# 4                  IN               259            118.0                2
# ...               ...               ...              ...              ...
# 17621              EG                 0              0.8                1
# 17622              IN                 0              0.1                1
# 17623              CM                 0              7.8                1
# 17624              CA                 0             10.4                1
# 17625              SA                 0              0.1                1
#
#        minutes_spent_on_exams  purchased
# 0                       15.81          0
# 1                       16.00          0
# 2                        0.93          0
# 3                       14.63          0
# 4                       16.48          0
# ...                       ...        ...
# 17621                    0.00          0
# 17622                    0.00          0
# 17623                    0.00          0
# 17624                    0.00          0
# 17625                    0.00          0
#
# [17626 rows x 6 columns]

# %%
cleaned_data = new_df.copy()
cleaned_data
# Out:
#       student_country  days_on_platform  minutes_watched  courses_started  \
# 0                  US               288            358.1                1
# 1                  SG               260              1.7                1
# 2                  TR               260             22.4                1
# 3                  KE               259             18.8                1
# 4                  IN               259            118.0                2
# ...               ...               ...              ...              ...
# 17621              EG                 0              0.8                1
# 17622              IN                 0              0.1                1
# 17623              CM                 0              7.8                1
# 17624              CA                 0             10.4                1
# 17625              SA                 0              0.1                1
#
#        minutes_spent_on_exams  purchased
# 0                       15.81          0
# 1                       16.00          0
# 2                        0.93          0
# 3                       14.63          0
# 4                       16.48          0
# ...                       ...        ...
# 17621                    0.00          0
# 17622                    0.00          0
# 17623                    0.00          0
# 17624                    0.00          0
# 17625                    0.00          0
#
# [17626 rows x 6 columns]

# %% [markdown]
# ### Splitting the Data

# %%
targets = cleaned_data['purchased']
inputs = cleaned_data.drop(['purchased'], axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size = 0.2, random_state = 365)

# %% [markdown]
# ### Encoding the Data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder

# %%
# Initialize the OrdinalEncoder
enc = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=170)

# Fit and transform the encoder on the training data
x_train_encoded = enc.fit_transform(x_train[["student_country"]])

# Create a new column "student_country_enc" in the training data
x_train["student_country_enc"] = x_train_encoded

# Drop the original "student_country" column from the training data
x_train.drop(["student_country"], axis=1, inplace=True)

# Now apply the encoder on the test data (with modification for unknown categories)
x_test_encoded = enc.transform(x_test[["student_country"]])

# Create a new column "student_country_enc" in the test data
x_test["student_country_enc"] = x_test_encoded

# Drop the original "student_country" column from the test data
x_test.drop(["student_country"], axis=1, inplace=True)

# Convert DataFrames to numpy ndarrays
x_train_array = np.asarray(x_train, dtype='float')
x_test_array = np.asarray(x_test, dtype='float')

# Now x_train_array, x_test_array, y_train, and y_test are ready for modeling
print(x_train_array[:5])
print(x_test_array[:5])
print(y_train[:5])
print(y_test[:5])
# Out:
# [[2.49e+02 2.46e+01 1.00e+00 0.00e+00 4.40e+01]
#  [4.40e+01 1.00e-01 1.00e+00 0.00e+00 1.54e+02]
#  [2.46e+02 4.00e-01 2.00e+00 9.40e+00 1.19e+02]
#  [2.90e+01 6.30e+00 1.00e+00 0.00e+00 4.40e+01]
#  [7.30e+01 4.54e+01 1.00e+00 3.71e+00 1.08e+02]]
# [[ 58.   67.2   1.    0.   67. ]
#  [ 14.   36.9   1.    0.  154. ]
#  [209.    0.8   1.    0.  110. ]
#  [ 38.    1.2   1.    0.  154. ]
#  [ 48.   65.4   4.    0.   12. ]]
# 3729     0
# 14748    0
# 343      0
# 15591    0
# 447      0
# Name: purchased, dtype: int64
# 14044    0
# 14786    1
# 6041     0
# 14999    0
# 14573    0
# Name: purchased, dtype: int64

# %% [markdown]
# # Creating Support Vector Machines

# %% [markdown]
# #### import relevant libraries

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn import svm, datasets
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score,\
classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1, 1))

# Fit the scaler on the training data and transform it
x_train_scaled = scaler.fit_transform(x_train_array)

# Transform the test data using the same scaler
x_test_scaled = scaler.transform(x_test_array)

# Now x_train_scaled and x_test_scaled are rescaled to the range (-1, 1)
print(x_train_scaled[:5])
print(x_test_scaled[:5])
# Out:
# [[ 0.70547945 -0.94973843 -1.         -1.         -0.46666667]
#  [-0.69863014 -1.         -1.         -1.          0.86666667]
#  [ 0.68493151 -0.99938455 -0.75       -0.52882206  0.44242424]
#  [-0.80136986 -0.98728075 -1.         -1.         -0.46666667]
#  [-0.5        -0.90706739 -1.         -0.81403509  0.30909091]]
# [[-0.60273973 -0.86234486 -1.         -1.         -0.18787879]
#  [-0.90410959 -0.92450508 -1.         -1.          0.86666667]
#  [ 0.43150685 -0.99856396 -1.         -1.          0.33333333]
#  [-0.73972603 -0.99774336 -1.         -1.          0.86666667]
#  [-0.67123288 -0.86603754 -0.25       -1.         -0.85454545]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the Support Vector Machine (SVM) classifier
svm_classifier = SVC(kernel='linear', random_state=0)
svm_poly = SVC(kernel='poly', random_state =0)
svm_rbf = SVC(kernel = 'rbf', random_state = 0)

# Fit the SVM classifier on the training data
svm_classifier.fit(x_train_array, y_train)
svm_poly.fit(x_train_array, y_train)
svm_rbf.fit(x_train_array, y_train)



# Make predictions on the test data
y_pred = svm_classifier.predict(x_test_array)
y_pred_poly = svm_poly.predict(x_test_array)
y_pred_rbf = svm_rbf.predict(x_test_array)

# Calculate the accuracy of the SVM classifier
accuracy = accuracy_score(y_test, y_pred)
accuracy_poly = accuracy_score(y_test, y_pred_poly)
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)


print("Accuracy of SVM Classifier:", accuracy)
print("Accuracy of Poly Classifier:", accuracy_poly)
print("Accuracy of rbf Classifier:", accuracy_rbf)
# Out:
# Accuracy of SVM Classifier: 0.9438457175269427
# Accuracy of Poly Classifier: 0.9302325581395349
# Accuracy of rbf Classifier: 0.9523539421440727

# %%
fig, ax = plt.subplots(figsize=(8, 5))
conf_matrix = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred),
                                    display_labels = ['Purchased','Not Purchased'],
                                    )
conf_matrix.plot(ax=ax);

# %%
fig, ax = plt.subplots(figsize=(8, 5))
conf_matrix = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_poly),
                                    display_labels = ['Purchased','Not Purchased'],
                                    )
conf_matrix.plot(ax=ax);

# %%
fig, ax = plt.subplots(figsize=(8, 5))
conf_matrix = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_rbf),
                                    display_labels = ['Purchased','Not Purchased'],
                                    )
conf_matrix.plot(ax=ax);

# %%
print(classification_report(y_test, y_pred, target_names = ['Purchased','Not Purchased']))
# Out:
#                precision    recall  f1-score   support
#
#     Purchased       0.95      0.99      0.97      3183
# Not Purchased       0.81      0.55      0.66       343
#
#      accuracy                           0.94      3526
#     macro avg       0.88      0.77      0.81      3526
#  weighted avg       0.94      0.94      0.94      3526

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC


# Define the parameter grid to search
tuned_parameters = [
    {'kernel': ['linear', 'poly', 'rbf'], 'C': np.arange(1, 11), 'gamma': ['scale', 'auto']}
]

# List of scoring metrics to consider
scores = ['precision', 'recall', 'f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()
    
    clf = GridSearchCV(SVC(), tuned_parameters, scoring="%s_macro" % score)
    clf.fit(x_train_scaled, y_train)
    
    print("Best Parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    
    print("Grid scores on development set:")
    print()
    
    means = clf.cv_results_["mean_test_score"]
    stds = clf.cv_results_["std_test_score"]
    for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
    
    # Use the best estimator to make predictions
    y_pred = clf.best_estimator_.predict(x_test_scaled)
    
    print("Detailed classification report:")
    print()
    print(classification_report(y_test, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best Parameters set found on development set:
#
# {'C': 9, 'gamma': 'scale', 'kernel': 'poly'}
#
# Grid scores on development set:
#
# 0.896 (+/-0.021) for {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.902 (+/-0.021) for {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 0.892 (+/-0.018) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.896 (+/-0.021) for {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 0.889 (+/-0.010) for {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 0.881 (+/-0.011) for {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.893 (+/-0.028) for {'C': 2, 'gamma': 'scale', 'kernel': 'linear'}
# 0.904 (+/-0.020) for {'C': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.897 (+/-0.016) for {'C': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.893 (+/-0.028) for {'C': 2, 'gamma': 'auto', 'kernel': 'linear'}
# 0.894 (+/-0.016) for {'C': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.887 (+/-0.015) for {'C': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.891 (+/-0.028) for {'C': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 0.904 (+/-0.019) for {'C': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.900 (+/-0.015) for {'C': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.891 (+/-0.028) for {'C': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 0.898 (+/-0.013) for {'C': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.889 (+/-0.013) for {'C': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.890 (+/-0.023) for {'C': 4, 'gamma': 'scale', 'kernel': 'linear'}
# 0.904 (+/-0.022) for {'C': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.900 (+/-0.015) for {'C': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.890 (+/-0.023) for {'C': 4, 'gamma': 'auto', 'kernel': 'linear'}
# 0.899 (+/-0.013) for {'C': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.891 (+/-0.015) for {'C': 4, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.891 (+/-0.023) for {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 0.904 (+/-0.022) for {'C': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.900 (+/-0.014) for {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.891 (+/-0.023) for {'C': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 0.898 (+/-0.013) for {'C': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.893 (+/-0.016) for {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.892 (+/-0.023) for {'C': 6, 'gamma': 'scale', 'kernel': 'linear'}
# 0.904 (+/-0.022) for {'C': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.899 (+/-0.014) for {'C': 6, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.892 (+/-0.023) for {'C': 6, 'gamma': 'auto', 'kernel': 'linear'}
# 0.899 (+/-0.013) for {'C': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.895 (+/-0.015) for {'C': 6, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.891 (+/-0.022) for {'C': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 0.904 (+/-0.022) for {'C': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 0.901 (+/-0.014) for {'C': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.891 (+/-0.022) for {'C': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 0.899 (+/-0.013) for {'C': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 0.896 (+/-0.014) for {'C': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.891 (+/-0.022) for {'C': 8, 'gamma': 'scale', 'kernel': 'linear'}
# 0.905 (+/-0.022) for {'C': 8, 'gamma': 'scale', 'kernel': 'poly'}
# 0.901 (+/-0.014) for {'C': 8, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.891 (+/-0.022) for {'C': 8, 'gamma': 'auto', 'kernel': 'linear'}
# 0.899 (+/-0.012) for {'C': 8, 'gamma': 'auto', 'kernel': 'poly'}
# 0.897 (+/-0.014) for {'C': 8, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.891 (+/-0.022) for {'C': 9, 'gamma': 'scale', 'kernel': 'linear'}
# 0.905 (+/-0.023) for {'C': 9, 'gamma': 'scale', 'kernel': 'poly'}
# 0.902 (+/-0.013) for {'C': 9, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.891 (+/-0.022) for {'C': 9, 'gamma': 'auto', 'kernel': 'linear'}
# 0.901 (+/-0.014) for {'C': 9, 'gamma': 'auto', 'kernel': 'poly'}
# 0.898 (+/-0.015) for {'C': 9, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.891 (+/-0.021) for {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 0.904 (+/-0.023) for {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 0.902 (+/-0.014) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.891 (+/-0.021) for {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 0.901 (+/-0.015) for {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 0.898 (+/-0.016) for {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3183
#            1       0.85      0.68      0.75       343
#
#     accuracy                           0.96      3526
#    macro avg       0.91      0.83      0.86      3526
# weighted avg       0.95      0.96      0.95      3526
#
# # Tuning hyper-parameters for recall
#
# Best Parameters set found on development set:
#
# {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
#
# Grid scores on development set:
#
# 0.782 (+/-0.013) for {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.831 (+/-0.016) for {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 0.801 (+/-0.020) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.782 (+/-0.013) for {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 0.777 (+/-0.007) for {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 0.774 (+/-0.011) for {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.785 (+/-0.013) for {'C': 2, 'gamma': 'scale', 'kernel': 'linear'}
# 0.834 (+/-0.015) for {'C': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.814 (+/-0.026) for {'C': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.785 (+/-0.013) for {'C': 2, 'gamma': 'auto', 'kernel': 'linear'}
# 0.799 (+/-0.011) for {'C': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.792 (+/-0.018) for {'C': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.788 (+/-0.015) for {'C': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 0.835 (+/-0.018) for {'C': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.818 (+/-0.021) for {'C': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.788 (+/-0.015) for {'C': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 0.809 (+/-0.017) for {'C': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.798 (+/-0.023) for {'C': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.790 (+/-0.014) for {'C': 4, 'gamma': 'scale', 'kernel': 'linear'}
# 0.835 (+/-0.019) for {'C': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.825 (+/-0.018) for {'C': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.790 (+/-0.014) for {'C': 4, 'gamma': 'auto', 'kernel': 'linear'}
# 0.812 (+/-0.018) for {'C': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.801 (+/-0.022) for {'C': 4, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.792 (+/-0.008) for {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 0.836 (+/-0.020) for {'C': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.827 (+/-0.015) for {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.792 (+/-0.008) for {'C': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 0.815 (+/-0.021) for {'C': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.804 (+/-0.022) for {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.793 (+/-0.011) for {'C': 6, 'gamma': 'scale', 'kernel': 'linear'}
# 0.838 (+/-0.017) for {'C': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.831 (+/-0.016) for {'C': 6, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.793 (+/-0.011) for {'C': 6, 'gamma': 'auto', 'kernel': 'linear'}
# 0.817 (+/-0.019) for {'C': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.807 (+/-0.022) for {'C': 6, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.793 (+/-0.012) for {'C': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 0.839 (+/-0.016) for {'C': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 0.833 (+/-0.017) for {'C': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.793 (+/-0.012) for {'C': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 0.817 (+/-0.019) for {'C': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 0.808 (+/-0.022) for {'C': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.793 (+/-0.012) for {'C': 8, 'gamma': 'scale', 'kernel': 'linear'}
# 0.840 (+/-0.018) for {'C': 8, 'gamma': 'scale', 'kernel': 'poly'}
# 0.834 (+/-0.015) for {'C': 8, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.793 (+/-0.012) for {'C': 8, 'gamma': 'auto', 'kernel': 'linear'}
# 0.819 (+/-0.014) for {'C': 8, 'gamma': 'auto', 'kernel': 'poly'}
# 0.809 (+/-0.022) for {'C': 8, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.794 (+/-0.011) for {'C': 9, 'gamma': 'scale', 'kernel': 'linear'}
# 0.840 (+/-0.019) for {'C': 9, 'gamma': 'scale', 'kernel': 'poly'}
# 0.835 (+/-0.016) for {'C': 9, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.794 (+/-0.011) for {'C': 9, 'gamma': 'auto', 'kernel': 'linear'}
# 0.821 (+/-0.018) for {'C': 9, 'gamma': 'auto', 'kernel': 'poly'}
# 0.812 (+/-0.023) for {'C': 9, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.794 (+/-0.014) for {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 0.840 (+/-0.019) for {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 0.835 (+/-0.017) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.794 (+/-0.014) for {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 0.823 (+/-0.020) for {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 0.812 (+/-0.023) for {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3183
#            1       0.85      0.68      0.75       343
#
#     accuracy                           0.96      3526
#    macro avg       0.91      0.83      0.86      3526
# weighted avg       0.95      0.96      0.95      3526
#
# # Tuning hyper-parameters for f1
#
# Best Parameters set found on development set:
#
# {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
#
# Grid scores on development set:
#
# 0.827 (+/-0.015) for {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.862 (+/-0.017) for {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 0.839 (+/-0.019) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.827 (+/-0.015) for {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 0.821 (+/-0.005) for {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 0.816 (+/-0.011) for {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.829 (+/-0.018) for {'C': 2, 'gamma': 'scale', 'kernel': 'linear'}
# 0.865 (+/-0.016) for {'C': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.849 (+/-0.023) for {'C': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.829 (+/-0.018) for {'C': 2, 'gamma': 'auto', 'kernel': 'linear'}
# 0.839 (+/-0.012) for {'C': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.831 (+/-0.016) for {'C': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.830 (+/-0.018) for {'C': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 0.865 (+/-0.018) for {'C': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.853 (+/-0.019) for {'C': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.830 (+/-0.018) for {'C': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 0.847 (+/-0.016) for {'C': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.836 (+/-0.019) for {'C': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.831 (+/-0.017) for {'C': 4, 'gamma': 'scale', 'kernel': 'linear'}
# 0.865 (+/-0.020) for {'C': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.857 (+/-0.017) for {'C': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.831 (+/-0.017) for {'C': 4, 'gamma': 'auto', 'kernel': 'linear'}
# 0.849 (+/-0.016) for {'C': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.839 (+/-0.019) for {'C': 4, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.833 (+/-0.013) for {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 0.866 (+/-0.021) for {'C': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.859 (+/-0.014) for {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.833 (+/-0.013) for {'C': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 0.850 (+/-0.018) for {'C': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.842 (+/-0.019) for {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.834 (+/-0.014) for {'C': 6, 'gamma': 'scale', 'kernel': 'linear'}
# 0.867 (+/-0.019) for {'C': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.861 (+/-0.015) for {'C': 6, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.834 (+/-0.014) for {'C': 6, 'gamma': 'auto', 'kernel': 'linear'}
# 0.853 (+/-0.017) for {'C': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.844 (+/-0.019) for {'C': 6, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.833 (+/-0.015) for {'C': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 0.868 (+/-0.018) for {'C': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 0.863 (+/-0.015) for {'C': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.833 (+/-0.015) for {'C': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 0.853 (+/-0.017) for {'C': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 0.845 (+/-0.019) for {'C': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.833 (+/-0.014) for {'C': 8, 'gamma': 'scale', 'kernel': 'linear'}
# 0.868 (+/-0.019) for {'C': 8, 'gamma': 'scale', 'kernel': 'poly'}
# 0.863 (+/-0.014) for {'C': 8, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.833 (+/-0.014) for {'C': 8, 'gamma': 'auto', 'kernel': 'linear'}
# 0.853 (+/-0.014) for {'C': 8, 'gamma': 'auto', 'kernel': 'poly'}
# 0.846 (+/-0.019) for {'C': 8, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.834 (+/-0.014) for {'C': 9, 'gamma': 'scale', 'kernel': 'linear'}
# 0.869 (+/-0.020) for {'C': 9, 'gamma': 'scale', 'kernel': 'poly'}
# 0.865 (+/-0.014) for {'C': 9, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.834 (+/-0.014) for {'C': 9, 'gamma': 'auto', 'kernel': 'linear'}
# 0.855 (+/-0.017) for {'C': 9, 'gamma': 'auto', 'kernel': 'poly'}
# 0.848 (+/-0.020) for {'C': 9, 'gamma': 'auto', 'kernel': 'rbf'}
# 0.834 (+/-0.016) for {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 0.869 (+/-0.020) for {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 0.865 (+/-0.014) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.834 (+/-0.016) for {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 0.856 (+/-0.019) for {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 0.848 (+/-0.021) for {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3183
#            1       0.85      0.68      0.75       343
#
#     accuracy                           0.96      3526
#    macro avg       0.91      0.83      0.86      3526
# weighted avg       0.95      0.96      0.95      3526

# %% [markdown]
# #### I would like to clarify that not all comments and analysis reports were included in this section of the project due to specific reasons. As a result, it would be inaccurate to consider this version as complete, even though it is a crucial and fundamental component of the project.

# %% [markdown]
# ### Thank you very much
